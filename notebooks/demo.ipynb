# %%
# Add relevant Jupyter notebook extensions

# %%
# You can double-check your Python path like this...
import sys  
import os
# Set the path to the uuv directory
project_root = r'D:\OneDrive - Nexus365\onedrive桌面\oxford study\third year\B1engineering_computation\scientific_coding\b1-coding-practical-mt24\uuv_mission'
sys.path.append(project_root)


print(sys.path)
# Out:
# ['C:\\Users\\19479\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'C:\\Users\\19479\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'C:\\Users\\19479\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'C:\\Users\\19479\\AppData\\Local\\Programs\\Python\\Python312', 'd:\\OneDrive - Nexus365\\onedrive桌面\\oxford study\\third year\\B1engineering_computation\\scientific_coding\\venv', '', 'd:\\OneDrive - Nexus365\\onedrive桌面\\oxford study\\third year\\B1engineering_computation\\scientific_coding\\venv\\Lib\\site-packages', 'd:\\OneDrive - Nexus365\\onedrive桌面\\oxford study\\third year\\B1engineering_computation\\scientific_coding\\venv\\Lib\\site-packages\\win32', 'd:\\OneDrive - Nexus365\\onedrive桌面\\oxford study\\third year\\B1engineering_computation\\scientific_coding\\venv\\Lib\\site-packages\\win32\\lib', 'd:\\OneDrive - Nexus365\\onedrive桌面\\oxford study\\third year\\B1engineering_computation\\scientific_coding\\venv\\Lib\\site-packages\\Pythonwin', 'D:\\OneDriv
# ...

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from dynamic import Submarine, ClosedLoop, Mission, Trajectory
from controller import Controller

sub = Submarine()
# Instantiate your controller (depending on your implementation)
controller = Controller(Kp=0.15,Kd=0.62)
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv("..\data\mission.csv") # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\19479\AppData\Local\Temp\ipykernel_14452\1145469283.py:9: SyntaxWarning: invalid escape sequence '\d'
#   mission = Mission.from_csv("..\data\mission.csv") # You must implement this method in the Mission class
